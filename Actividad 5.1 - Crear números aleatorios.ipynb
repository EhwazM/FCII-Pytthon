# %%
def RandomGenerator(mult, incr, seed, mod, iter):

    randnum = [seed]

    for i in range(iter):
        
        seed = (((mult * seed) + c) % mod) / mod
        randnum.append(seed)
    
    return randnum

# a = 997
# c = 23
# x = 137
# m = 1023

a = 20
c = 24
x = 28
m = 7104

print(RandomGenerator(a, c, x, m, 50))
# Out:
# [28, 0.08220720720720721, 0.003609817587858128, 0.0033885411531189703, 0.00338791819018333, 0.003387916436346237, 0.0033879164314086323, 0.0033879164313947315, 0.0033879164313946925, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0.003387916431394692, 0
# ...
