# %%
import numpy as np
from numpy.random import uniform as uni
import matplotlib.pyplot as plt

f = lambda x: np.sin(x)

def Transform(a, b, u, f):
    x = a + (b -a) * u
    return f(x)

a, b = (0,5)
n = 1000

yRandom = uni (0, 1, n)
functionValue = Transform(a,b,yRandom, f)
integral = (b - a)*np.mean(functionValue)

print(integral)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      12 n = 1000
#      14 yRandom = uni (0, 1, n)
# ---> 15 functionValue = Transform(a,b,yRandom, f)
#      16 integral = (b - a)*np.mean(functionValue)
#      18 print(integral)
#
# Cell In[1], line 9, in Transform(a, b, u, f)
#       7 def Transform(a, b, u, f):
#       8     x = a + (b -a) * u
# ----> 9     return f(x)
#
# Cell In[1], line 5, in <lambda>(x)
#       2 from numpy.random import uniform as uni
#       3 import matplotlib.pyplot as plt
# ----> 5 f = lambda x: sin(x)
#       7 def Transform(a, b, u, f):
#       8     x = a + (b -a) * u
#
# NameError: name 'sin' is not defined

# %%
import numpy as np
from numpy.random import uniform as uni
import matplotlib.pyplot as plt

f = lambda x: 1/(np.exp(x) + 1)

def Transform(a, b, u, f):
    x = (1/u) - 1
    return ((1/u**2) * f(x))

a, b = (0,1e2028)
n = 1000

yRandom = uni (0, 1, n)
functionValue = Transform(a,b,yRandom, f)
integral = np.mean(functionValue)

print(integral)
# Out:
# 0.6806952633304
