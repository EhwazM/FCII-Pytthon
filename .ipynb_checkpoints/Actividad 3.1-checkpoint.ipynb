# %%
import numpy as np

option = 0

while not(option == 2):

    precio = 0

    print("1. Calcule su factura")
    print("2. Salir")

    option = int(input("\nDigite el número que correpende a su petición: \n"))

    if option == 1:
        
        estrato = int(input("Digite su estrato:"))
        m3 = int(input("Digite la cantidad de metros cúbicos de gas usado (no mienta por favor):"))
        print("\n")

        if estrato == 1:

            precio = m3 * 1034
            

        elif estrato == 2:

            precio = m3 * 1299

        elif estrato == 3 or estrato == 4:

            precio = m3 * 2256

        elif estrato == 5 or estrato == 6:

            precio = m3 * 2707

        else:

            print("Algo ha fallado, digite correctamente su estrato.\n")

        print("El precio a pagar de su factura es de: $", precio, " pesos. Escriba SI en caso de estar de acuerdo, si no está de acuerdo, pos de malas.\n")

        input("Escriba 'SI':") # Esta parte solo existe para que se pueda observar el precio antes de cambiar de ciclo.
# Out:
# 1. Calcule su factura
# 2. Salir
# Digite el número que correpende a su petición:
#  1
# Digite su estrato: 4
# Digite la cantidad de metros cúbicos de gas usado (no mienta por favor): 123
# El precio a pagar de su factura es de: $ 277488  pesos. Escriba SI en caso de estar de acuerdo, si no está de acuerdo, pos de malas.
